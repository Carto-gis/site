# %% [markdown]
# # Lesson 2: Visual hierarchy and colors

# %% [markdown]
# Main topics:
#
# - Visual hierarchy in cartography
# - Colors in cartography
# - Cartography as an art
#
#
#
# ## Lecture slides
#
# * Some maps and images are removed from published version of slides due to copyright.
#
# <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vTdj5O4w63pSxZHIwHlx7oVrhhArHddxmdp7-2k12Iu8WChq5i7n1iYIn88LYm_Wg/pubembed?start=false&loop=false&delayms=60000" frameborder="0" width="640" height="389" allowfullscreen="true" mozallowfullscreen="true" webkitallowfullscreen="true"></iframe>
#
# Guest speaker - Tuomas Väisänen:
#
# <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vTcS2sbPd6yqhxPYFMPRrNtt25stjmpD4pPKXZ4Ko0kLNqW6l39RJsqFBDKldNjqw/pubembed?start=false&loop=false&delayms=60000" frameborder="0" width="640" height="389" allowfullscreen="true" mozallowfullscreen="true" webkitallowfullscreen="true"></iframe>
#
# ## Video recording
#
# To be added.
